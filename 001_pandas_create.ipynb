# %%
# 'U/A' rate movie requires age more than 18,
# or a guardian to be present to watch
age = 12
with_guardian = False
can_watch = age >= 18 or with_guardian

print(can_watch)

# %% [markdown]
# ## Pandas - Create, Read, Write
#
# ### isntallation
# `pip install pandas`

# %%
import pandas as pd

df = pd.DataFrame({
    "Name": ["John", "Dave", "Mike"],
    "Age": [22, 26, 35],
    "Education": ["PG", "UG", "Dr"]
})

print(df)

# %% [markdown]
# Descriptive statistics about the data and its tendency

# %%
df.describe()

# %%
names = df["Name"]
print(names)

ages = df["Age"]
print(ages)
print(ages.max())
